# %% [markdown]
# # Extracting Features from Images
# ##### Obtaining pixel intensities for image and transforming those into usable features

# %% [markdown]
# #### Installation of opencv may be required
#
# OpenCV == Open Source Computer Vision Library

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting numpy>=2 (from opencv-python)
#   Using cached numpy-2.4.4-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/40.2 MB ? eta -:--:--
#    - -------------------------------------- 1.6/40.2 MB 5.0 MB/s eta 0:00:08
#    -- ------------------------------------- 2.6/40.2 MB 5.2 MB/s eta 0:00:08
#    --- ------------------------------------ 3.1/40.2 MB 4.7 MB/s eta 0:00:08
#    --- ------------------------------------ 3.9/40.2 MB 4.5 MB/s eta 0:00:09
#    ---- ----------------------------------- 5.0/40.2 MB 4.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.2/40.2 MB 4.3 MB/s eta 0:00:09
#    ------ --------------------------------- 6.3/40.2 MB 4.3 MB/s eta 0:00:08
#    ------- -------------------------------- 7.3/40.2 MB 4.2 MB/s eta 0:00:08
#    -------- ------------------------------- 8.4/40.2 MB 4.3 MB/s eta 0:00:08
#    --------- ------------------------------ 9.4/40.2 MB 4.3 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.7/40.2 MB 4.5 MB/s eta 0:00:07
#    ----------- ---------------------------- 11.5/40.2 MB 4.5 MB/s eta 0:00:07
#    ------------ --------------------------- 12.6/40.2 MB 4.5 MB/s eta 0:00:07
#    ------------- -------------------------- 13.4/40.2 MB 4.5 MB/s eta 0:00:07
#    -------------- ------------------------- 14.4/40.2 MB 4.5 MB/s eta 0:00:06
#    --------------- ------------------------ 15.2/40.2 MB 4.5 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.3/40.2 MB 4.5 MB/s eta 0:00:06
#    ---------------- ----------------------- 17.0/40.2 MB 4.5 MB/s eta 0:00:06
#    ----------------- ---------------------- 17.6/40.2 MB 4.5 MB/s eta 0:00:06
#    ------------------ --------------------- 18.6/40.2 MB 4.4 MB/s eta 0:00:05
#    ------------------- -------------------- 19.4/40.2 MB 4.4 MB/s eta 0:00:05
#    -------------------- ------------------- 20.4/40.2 MB 4.4 MB/s eta 0:00:05
#    --------------------- ------------------ 21.5/40.2 MB 4.4 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.8/40.2 MB 4.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 23.6/40.2 MB 4.5 MB/s eta 0:00:04
#    ------------------------ --------------- 24.9/40.2 MB 4.5 MB/s eta 0:00:04
#    ------------------------- -------------- 26.0/40.2 MB 4.5 MB/s eta 0:00:04
#    --------------------------- ------------ 27.3/40.2 MB 4.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 28.3/40.2 MB 4.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 29.4/40.2 MB 4.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 30.1/40.2 MB 4.6 MB/s eta 0:00:03
#    ------------------------------- -------- 31.2/40.2 MB 4.6 MB/s eta 0:00:02
#    -------------------------------- ------- 32.2/40.2 MB 4.6 MB/s eta 0:00:02
#    --------------------------------- ------ 33.3/40.2 MB 4.6 MB/s eta 0:00:02
#    --------------------------------- ------ 34.1/40.2 MB 4.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 35.1/40.2 MB 4.6 MB/s eta 0:00:02
#    ------------------------------------ --- 36.4/40.2 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------- -- 37.5/40.2 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 38.5/40.2 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  39.6/40.2 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 4.6 MB/s  0:00:08
# Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.4 MB 5.8 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/12.4 MB 5.8 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/12.4 MB 5.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/12.4 MB 1.9 MB/s eta 0:00:06
#    -------- ------------------------------- 2.6/12.4 MB 2.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.4/12.4 MB 2.7 MB/s eta 0:00:04
#    ------------- -------------------------- 4.2/12.4 MB 2.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.2/12.4 MB 3.1 MB/s eta 0:00:03
#    ------------------ --------------------- 5.8/12.4 MB 3.1 MB/s eta 0:00:03
#    --------------------- ------------------ 6.8/12.4 MB 3.2 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.4 MB 3.3 MB/s eta 0:00:02
#    ------------------------- -------------- 7.9/12.4 MB 3.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.4 MB 3.3 MB/s eta 0:00:02
#    ------------------------------- -------- 9.7/12.4 MB 3.3 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.4 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.4 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 3.4 MB/s  0:00:03
# Installing collected packages: numpy, opencv-python
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    ---------------------------------------- 2/2 [opencv-python]
#
# Successfully installed numpy-2.4.4 opencv-python-4.13.0.92
# WARNING: Cache entry deserialization failed, entry ignored
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\jorge\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import cv2

# %% [markdown]
# #### Load an image from which to extract RGB pixel intensities

# %%
# Image with dimensions 173x130
imagePath = '../data/dog.jpg'

image = cv2.imread(imagePath)

# %% [markdown]
# #### View image using matplotlib

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

plt.imshow(image)

# %% [markdown]
# #### Image array contains RGB values for each pixel in the image

# %%
image.shape
# Out:
# (130, 173, 3)

# %%
image
# Out:
# array([[[199, 171, 164],
#         [227, 206, 198],
#         [249, 237, 231],
#         ...,
#         [253, 242, 234],
#         [254, 243, 235],
#         [254, 243, 235]],
#
#        [[221, 195, 188],
#         [228, 209, 201],
#         [246, 237, 228],
#         ...,
#         [254, 243, 235],
#         [255, 243, 237],
#         [254, 242, 236]],
#
#        [[227, 209, 198],
#         [225, 210, 201],
#         [238, 231, 222],
#         ...,
#         [254, 242, 236],
#         [254, 242, 238],
#         [253, 241, 237]],
#
#        ...,
#
#        [[203, 207, 208],
#         [199, 203, 204],
#         [200, 202, 203],
#         ...,
#         [ 98, 112, 118],
#         [ 99, 113, 119],
#         [ 98, 112, 118]],
#
#        [[201, 202, 206],
#         [203, 204, 208],
#         [204, 205, 209],
#         ...,
#         [103, 115, 119],
#         [107, 119, 123],
#         [104, 116, 120]],
#
#        [[200, 201, 205],
#         [201, 202, 206],
#         [203, 204, 208],
#         ...,
#         [106, 118, 122],
#         [111, 123, 127],
#         [108, 120, 124]]], shape=(130, 173, 3), dtype=uint8)

# %% [markdown]
# #### Each pixel has RGB intensities

# %%
image[0][0]
# Out:
# array([199, 171, 164], dtype=uint8)

# %% [markdown]
# #### Scale this image to a smaller size

# %%
size=(32, 32)
resized_image_feature_vector = cv2.resize(image, size)

# %%
plt.imshow(resized_image_feature_vector)

# %%
resized_image_feature_vector.shape
# Out:
# (32, 32, 3)

# %%
resized_image_feature_vector
# Out:
# array([[[244, 237, 228],
#         [251, 254, 253],
#         [255, 250, 242],
#         ...,
#         [253, 247, 242],
#         [255, 245, 238],
#         [254, 243, 236]],
#
#        [[126, 118, 108],
#         [237, 218, 211],
#         [166, 156, 144],
#         ...,
#         [255, 246, 242],
#         [255, 245, 241],
#         [254, 241, 233]],
#
#        [[254, 253, 251],
#         [255, 254, 252],
#         [254, 253, 251],
#         ...,
#         [250, 239, 230],
#         [243, 224, 214],
#         [190, 177, 165]],
#
#        ...,
#
#        [[206, 206, 210],
#         [208, 209, 213],
#         [207, 208, 212],
#         ...,
#         [119, 131, 138],
#         [121, 135, 141],
#         [115, 129, 136]],
#
#        [[207, 208, 211],
#         [211, 209, 212],
#         [213, 211, 214],
#         ...,
#         [110, 124, 130],
#         [104, 118, 124],
#         [107, 121, 127]],
#
#        [[202, 204, 206],
#         [211, 210, 213],
#         [211, 209, 211],
#         ...,
#         [119, 132, 137],
#         [100, 113, 118],
#         [ 99, 112, 118]]], shape=(32, 32, 3), dtype=uint8)

# %% [markdown]
# #### Image array can be flattened into a one-dimensional array

# %%
resized_flattened_image_feature_vector = resized_image_feature_vector.flatten()

# %%
len(resized_flattened_image_feature_vector)
# Out:
# 3072

# %%
image_grayscale = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE )

# %%
plt.imshow(image_grayscale)

# %%
image_grayscale.shape
# Out:
# (130, 173)

# %%
image_grayscale
# Out:
# array([[172, 206, 237, ..., 241, 242, 242],
#        [196, 209, 235, ..., 242, 243, 242],
#        [208, 209, 229, ..., 242, 242, 241],
#        ...,
#        [207, 203, 202, ..., 112, 113, 112],
#        [203, 205, 206, ..., 115, 119, 116],
#        [202, 203, 205, ..., 118, 123, 120]], shape=(130, 173), dtype=uint8)

# %%
import numpy as np

expanded_image_grayscale = np.expand_dims(image_grayscale, axis=2)
expanded_image_grayscale.shape
# Out:
# (130, 173, 1)

# %%
expanded_image_grayscale
# Out:
# array([[[172],
#         [206],
#         [237],
#         ...,
#         [241],
#         [242],
#         [242]],
#
#        [[196],
#         [209],
#         [235],
#         ...,
#         [242],
#         [243],
#         [242]],
#
#        [[208],
#         [209],
#         [229],
#         ...,
#         [242],
#         [242],
#         [241]],
#
#        ...,
#
#        [[207],
#         [203],
#         [202],
#         ...,
#         [112],
#         [113],
#         [112]],
#
#        [[203],
#         [205],
#         [206],
#         ...,
#         [115],
#         [119],
#         [116]],
#
#        [[202],
#         [203],
#         [205],
#         ...,
#         [118],
#         [123],
#         [120]]], shape=(130, 173, 1), dtype=uint8)
